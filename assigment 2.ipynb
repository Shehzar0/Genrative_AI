# %%
#length of list
a = ["ali" , "rehman" , "noman" , "faizan" , "zeeshan"]
print("the length is: " , len(a))
# Out:
# the length is:  5

# %%
#sum of numeric items
my_list = [1 , 2 , 3  , 4 , 5]
print("the sum is:" ,sum(my_list))
# Out:
# the sum is: 15

# %%
#largest number of numeric list
largest_number = [23 , 1 , 4 , 6 ,9 , 67, 54]
print("the largest number of the list is:" ,max(largest_number))
# Out:
# the largest number of the list is: 67

# %%
#find a number of smaller than 5
number = [3, 4, 6, 2, 7, 9, 23, 42, 67, 12, 32]
total =[]
for n in number:
    if n <= 5:
        total.append(n)
print(total)
# Out:
# [3, 4, 2]
